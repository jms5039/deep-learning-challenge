# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
import shutil
from google.colab import files

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Dropping non-beneficial ID columns, 'EIN' and 'NAME', and additional irrelevant columns
application_df = application_df.drop(columns=['EIN', 'NAME', 'SPECIAL_CONSIDERATIONS', 'ASK_AMT'])

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE    17
# AFFILIATION          6
# CLASSIFICATION      71
# USE_CASE             5
# ORGANIZATION         4
# STATUS               2
# INCOME_AMT           9
# IS_SUCCESSFUL        2
# dtype: int64

# %%
# Binning APPLICATION_TYPE with more bins for rare occurrences
application_counts = application_df['APPLICATION_TYPE'].value_counts()
application_types_to_replace = list(application_counts[application_counts < 1000].index)
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app, 'Other')

# Binning CLASSIFICATION with more bins for rare occurrences
classification_counts = application_df['CLASSIFICATION'].value_counts()
classifications_to_replace = list(classification_counts[classification_counts < 1000].index)
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls, 'Other')

# %%
# Converting categorical data to numeric with pd.get_dummies
application_df = pd.get_dummies(application_df)

# %%
# Splitting data into features and target
X = application_df.drop(columns=['IS_SUCCESSFUL'])
y = application_df['IS_SUCCESSFUL']

# Splitting data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Creating a StandardScaler instance
scaler = StandardScaler()

# Fitting the StandardScaler
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the filepath where you want to save the weights
checkpoint_path = "trained_charity_weights.{epoch:02d}.hdf5"

# Create a ModelCheckpoint callback
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,  # Save only the weights
    save_freq="epoch",  # Save weights every epoch
    period=5  # Save weights every five epochs
)

# Defining the model with more neurons and hidden layers, and different activation functions
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 200
hidden_nodes_layer2 = 100
hidden_nodes_layer3 = 50

nn = tf.keras.models.Sequential()

# First hidden layer with Leaky ReLU activation
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation=tf.keras.layers.LeakyReLU(alpha=0.01)))

# Second hidden layer with ELU activation
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='elu'))

# Third hidden layer with tanh activation
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='tanh'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 200)               7600
#
#  dense_1 (Dense)             (None, 100)               20100
#
#  dense_2 (Dense)             (None, 50)                5050
#
#  dense_3 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 32801 (128.13 KB)
# Trainable params: 32801 (128.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compiling the model with different learning rate and optimizer
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
nn.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
# Train the model
# Train the model with the added callback
# Training the model with increased epochs
fit_model = nn.fit(
    X_train_scaled,
    y_train,
    epochs=150,
    callbacks=[checkpoint_callback]  # Add the ModelCheckpoint callback
)
# Out:
# Epoch 1/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5815 - accuracy: 0.7131
# Epoch 2/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5616 - accuracy: 0.7287
# Epoch 3/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5578 - accuracy: 0.7296
# Epoch 4/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5555 - accuracy: 0.7304
# Epoch 5/150
# 800/804 [============================>.] - ETA: 0s - loss: 0.5545 - accuracy: 0.7316
# Epoch 5: saving model to trained_charity_weights.05.hdf5
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5546 - accuracy: 0.7316
# Epoch 6/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5531 - accuracy: 0.7317
# Epoch 7/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5525 - accuracy: 0.7320
# Epoch 8/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5516 - accuracy: 0.7323
# Epoch 9/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5510 - accuracy: 0.7321
# Epoch 10/150
# 800/804 [============================>.] - ETA: 0s - loss: 0.5509 - accuracy: 0.7327
# Epoch 10: saving model to trained_charity_weights.10.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5508 - accuracy: 0.7329
# Epoch 11/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5503 - accuracy: 0.7326
# Epoch 12/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5497 - accuracy: 0.7329
# Epoch 13/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5496 - accuracy: 0.7334
# Epoch 14/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5492 - accuracy: 0.7323
# Epoch 15/150
# 795/804 [============================>.] - ETA: 0s - loss: 0.5480 - accuracy: 0.7347
# Epoch 15: saving model to trained_charity_weights.15.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5485 - accuracy: 0.7343
# Epoch 16/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5490 - accuracy: 0.7333
# Epoch 17/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5485 - accuracy: 0.7341
# Epoch 18/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5480 - accuracy: 0.7345
# Epoch 19/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5481 - accuracy: 0.7339
# Epoch 20/150
# 799/804 [============================>.] - ETA: 0s - loss: 0.5478 - accuracy: 0.7351
# Epoch 20: saving model to trained_charity_weights.20.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5480 - accuracy: 0.7348
# Epoch 21/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5475 - accuracy: 0.7349
# Epoch 22/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5477 - accuracy: 0.7348
# Epoch 23/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5473 - accuracy: 0.7353
# Epoch 24/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5472 - accuracy: 0.7345
# Epoch 25/150
# 784/804 [============================>.] - ETA: 0s - loss: 0.5467 - accuracy: 0.7358
# Epoch 25: saving model to trained_charity_weights.25.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5470 - accuracy: 0.7352
# Epoch 26/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5466 - accuracy: 0.7349
# Epoch 27/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5464 - accuracy: 0.7352
# Epoch 28/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5469 - accuracy: 0.7358
# Epoch 29/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5463 - accuracy: 0.7354
# Epoch 30/150
# 794/804 [============================>.] - ETA: 0s - loss: 0.5467 - accuracy: 0.7362
# Epoch 30: saving model to trained_charity_weights.30.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5465 - accuracy: 0.7362
# Epoch 31/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5461 - accuracy: 0.7366
# Epoch 32/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5458 - accuracy: 0.7365
# Epoch 33/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5460 - accuracy: 0.7358
# Epoch 34/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5457 - accuracy: 0.7364
# Epoch 35/150
# 794/804 [============================>.] - ETA: 0s - loss: 0.5458 - accuracy: 0.7363
# Epoch 35: saving model to trained_charity_weights.35.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5455 - accuracy: 0.7364
# Epoch 36/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5453 - accuracy: 0.7367
# Epoch 37/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5453 - accuracy: 0.7360
# Epoch 38/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5448 - accuracy: 0.7368
# Epoch 39/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5449 - accuracy: 0.7376
# Epoch 40/150
# 804/804 [==============================] - ETA: 0s - loss: 0.5449 - accuracy: 0.7371
# Epoch 40: saving model to trained_charity_weights.40.hdf5
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5449 - accuracy: 0.7371
# Epoch 41/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5448 - accuracy: 0.7369
# Epoch 42/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7381
# Epoch 43/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7369
# Epoch 44/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5447 - accuracy: 0.7366
# Epoch 45/150
# 801/804 [============================>.] - ETA: 0s - loss: 0.5443 - accuracy: 0.7376
# Epoch 45: saving model to trained_charity_weights.45.hdf5
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5447 - accuracy: 0.7372
# Epoch 46/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5446 - accuracy: 0.7383
# Epoch 47/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5443 - accuracy: 0.7379
# Epoch 48/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5441 - accuracy: 0.7378
# Epoch 49/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5441 - accuracy: 0.7386
# Epoch 50/150
# 804/804 [==============================] - ETA: 0s - loss: 0.5440 - accuracy: 0.7384
# Epoch 50: saving model to trained_charity_weights.50.hdf5
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5440 - accuracy: 0.7384
# Epoch 51/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5438 - accuracy: 0.7378
# Epoch 52/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5438 - accuracy: 0.7387
# Epoch 53/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5437 - accuracy: 0.7380
# Epoch 54/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5438 - accuracy: 0.7380
# Epoch 55/150
# 797/804 [============================>.] - ETA: 0s - loss: 0.5431 - accuracy: 0.7386
# Epoch 55: saving model to trained_charity_weights.55.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5435 - accuracy: 0.7384
# Epoch 56/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5436 - accuracy: 0.7384
# Epoch 57/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5436 - accuracy: 0.7384
# Epoch 58/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5434 - accuracy: 0.7381
# Epoch 59/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5433 - accuracy: 0.7381
# Epoch 60/150
# 788/804 [============================>.] - ETA: 0s - loss: 0.5433 - accuracy: 0.7378
# Epoch 60: saving model to trained_charity_weights.60.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5434 - accuracy: 0.7379
# Epoch 61/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5434 - accuracy: 0.7386
# Epoch 62/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5428 - accuracy: 0.7380
# Epoch 63/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5431 - accuracy: 0.7388
# Epoch 64/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5432 - accuracy: 0.7392
# Epoch 65/150
# 795/804 [============================>.] - ETA: 0s - loss: 0.5426 - accuracy: 0.7386
# Epoch 65: saving model to trained_charity_weights.65.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5427 - accuracy: 0.7386
# Epoch 66/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5430 - accuracy: 0.7390
# Epoch 67/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5429 - accuracy: 0.7383
# Epoch 68/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5427 - accuracy: 0.7388
# Epoch 69/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5425 - accuracy: 0.7393
# Epoch 70/150
# 786/804 [============================>.] - ETA: 0s - loss: 0.5428 - accuracy: 0.7383
# Epoch 70: saving model to trained_charity_weights.70.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5426 - accuracy: 0.7383
# Epoch 71/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5425 - accuracy: 0.7388
# Epoch 72/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5426 - accuracy: 0.7379
# Epoch 73/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5425 - accuracy: 0.7386
# Epoch 74/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5424 - accuracy: 0.7385
# Epoch 75/150
# 786/804 [============================>.] - ETA: 0s - loss: 0.5424 - accuracy: 0.7385
# Epoch 75: saving model to trained_charity_weights.75.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5425 - accuracy: 0.7388
# Epoch 76/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5426 - accuracy: 0.7386
# Epoch 77/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5422 - accuracy: 0.7391
# Epoch 78/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5419 - accuracy: 0.7394
# Epoch 79/150
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5419 - accuracy: 0.7389
# Epoch 80/150
# 798/804 [============================>.] - ETA: 0s - loss: 0.5423 - accuracy: 0.7391
# Epoch 80: saving model to trained_charity_weights.80.hdf5
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5421 - accuracy: 0.7391
# Epoch 81/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5421 - accuracy: 0.7391
# Epoch 82/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5421 - accuracy: 0.7395
# Epoch 83/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5418 - accuracy: 0.7385
# Epoch 84/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5419 - accuracy: 0.7389
# Epoch 85/150
# 803/804 [============================>.] - ETA: 0s - loss: 0.5417 - accuracy: 0.7387
# Epoch 85: saving model to trained_charity_weights.85.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5417 - accuracy: 0.7386
# Epoch 86/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5416 - accuracy: 0.7393
# Epoch 87/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5418 - accuracy: 0.7390
# Epoch 88/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5417 - accuracy: 0.7388
# Epoch 89/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5417 - accuracy: 0.7390
# Epoch 90/150
# 782/804 [============================>.] - ETA: 0s - loss: 0.5408 - accuracy: 0.7396
# Epoch 90: saving model to trained_charity_weights.90.hdf5
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5412 - accuracy: 0.7394
# Epoch 91/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5416 - accuracy: 0.7394
# Epoch 92/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5416 - accuracy: 0.7386
# Epoch 93/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5415 - accuracy: 0.7387
# Epoch 94/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5412 - accuracy: 0.7394
# Epoch 95/150
# 801/804 [============================>.] - ETA: 0s - loss: 0.5418 - accuracy: 0.7392
# Epoch 95: saving model to trained_charity_weights.95.hdf5
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5416 - accuracy: 0.7393
# Epoch 96/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5413 - accuracy: 0.7399
# Epoch 97/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5413 - accuracy: 0.7386
# Epoch 98/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5415 - accuracy: 0.7390
# Epoch 99/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5411 - accuracy: 0.7395
# Epoch 100/150
# 790/804 [============================>.] - ETA: 0s - loss: 0.5410 - accuracy: 0.7400
# Epoch 100: saving model to trained_charity_weights.100.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5412 - accuracy: 0.7399
# Epoch 101/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5411 - accuracy: 0.7401
# Epoch 102/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5410 - accuracy: 0.7394
# Epoch 103/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5411 - accuracy: 0.7392
# Epoch 104/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5409 - accuracy: 0.7396
# Epoch 105/150
# 802/804 [============================>.] - ETA: 0s - loss: 0.5409 - accuracy: 0.7400
# Epoch 105: saving model to trained_charity_weights.105.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5410 - accuracy: 0.7399
# Epoch 106/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5408 - accuracy: 0.7396
# Epoch 107/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5408 - accuracy: 0.7399
# Epoch 108/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7407
# Epoch 109/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5408 - accuracy: 0.7399
# Epoch 110/150
# 793/804 [============================>.] - ETA: 0s - loss: 0.5410 - accuracy: 0.7402
# Epoch 110: saving model to trained_charity_weights.110.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5407 - accuracy: 0.7406
# Epoch 111/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5407 - accuracy: 0.7399
# Epoch 112/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5409 - accuracy: 0.7396
# Epoch 113/150
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5407 - accuracy: 0.7402
# Epoch 114/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5405 - accuracy: 0.7400
# Epoch 115/150
# 797/804 [============================>.] - ETA: 0s - loss: 0.5412 - accuracy: 0.7393
# Epoch 115: saving model to trained_charity_weights.115.hdf5
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5407 - accuracy: 0.7398
# Epoch 116/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5405 - accuracy: 0.7403
# Epoch 117/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5407 - accuracy: 0.7401
# Epoch 118/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5403 - accuracy: 0.7400
# Epoch 119/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5404 - accuracy: 0.7399
# Epoch 120/150
# 798/804 [============================>.] - ETA: 0s - loss: 0.5402 - accuracy: 0.7401
# Epoch 120: saving model to trained_charity_weights.120.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5404 - accuracy: 0.7400
# Epoch 121/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5404 - accuracy: 0.7407
# Epoch 122/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5405 - accuracy: 0.7400
# Epoch 123/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5399 - accuracy: 0.7390
# Epoch 124/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5403 - accuracy: 0.7404
# Epoch 125/150
# 795/804 [============================>.] - ETA: 0s - loss: 0.5398 - accuracy: 0.7405
# Epoch 125: saving model to trained_charity_weights.125.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5401 - accuracy: 0.7404
# Epoch 126/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5402 - accuracy: 0.7398
# Epoch 127/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5401 - accuracy: 0.7394
# Epoch 128/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5401 - accuracy: 0.7405
# Epoch 129/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5402 - accuracy: 0.7402
# Epoch 130/150
# 801/804 [============================>.] - ETA: 0s - loss: 0.5403 - accuracy: 0.7400
# Epoch 130: saving model to trained_charity_weights.130.hdf5
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5401 - accuracy: 0.7401
# Epoch 131/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5402 - accuracy: 0.7392
# Epoch 132/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5399 - accuracy: 0.7402
# Epoch 133/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5399 - accuracy: 0.7398
# Epoch 134/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5402 - accuracy: 0.7402
# Epoch 135/150
# 800/804 [============================>.] - ETA: 0s - loss: 0.5398 - accuracy: 0.7402
# Epoch 135: saving model to trained_charity_weights.135.hdf5
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5399 - accuracy: 0.7403
# Epoch 136/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5397 - accuracy: 0.7397
# Epoch 137/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5398 - accuracy: 0.7400
# Epoch 138/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5397 - accuracy: 0.7408
# Epoch 139/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5396 - accuracy: 0.7402
# Epoch 140/150
# 803/804 [============================>.] - ETA: 0s - loss: 0.5399 - accuracy: 0.7401
# Epoch 140: saving model to trained_charity_weights.140.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5398 - accuracy: 0.7402
# Epoch 141/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5398 - accuracy: 0.7399
# Epoch 142/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5396 - accuracy: 0.7405
# Epoch 143/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5396 - accuracy: 0.7400
# Epoch 144/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5399 - accuracy: 0.7400
# Epoch 145/150
# 797/804 [============================>.] - ETA: 0s - loss: 0.5394 - accuracy: 0.7402
# Epoch 145: saving model to trained_charity_weights.145.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5398 - accuracy: 0.7399
# Epoch 146/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5395 - accuracy: 0.7399
# Epoch 147/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5396 - accuracy: 0.7402
# Epoch 148/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5394 - accuracy: 0.7402
# Epoch 149/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5396 - accuracy: 0.7404
# Epoch 150/150
# 798/804 [============================>.] - ETA: 0s - loss: 0.5395 - accuracy: 0.7401
# Epoch 150: saving model to trained_charity_weights.150.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5396 - accuracy: 0.7401

# %%
# Evaluating the model
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5548 - accuracy: 0.7261 - 559ms/epoch - 2ms/step
# Loss: 0.5547785758972168, Accuracy: 0.726064145565033

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity_Optimization_4.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Download the file
files.download("AlphabetSoupCharity_Optimization_4.h5")
