# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
import shutil
from google.colab import files

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Dropping non-beneficial ID columns, 'EIN' and 'NAME', and additional irrelevant columns
application_df = application_df.drop(columns=['EIN', 'NAME', 'SPECIAL_CONSIDERATIONS'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-d664f73c316b> in <cell line: 2>()
#       1 # Dropping non-beneficial ID columns, 'EIN' and 'NAME', and additional irrelevant columns
# ----> 2 application_df = application_df.drop(columns=['EIN', 'NAME', 'SPECIAL_CONSIDERATIONS'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# ...

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE      17
# AFFILIATION            6
# CLASSIFICATION        71
# USE_CASE               5
# ORGANIZATION           4
# STATUS                 2
# INCOME_AMT             9
# ASK_AMT             8747
# IS_SUCCESSFUL          2
# dtype: int64

# %%
# Binning APPLICATION_TYPE with more bins for rare occurrences
application_counts = application_df['APPLICATION_TYPE'].value_counts()
application_types_to_replace = list(application_counts[application_counts < 1000].index)
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app, 'Other')

# Binning CLASSIFICATION with more bins for rare occurrences
classification_counts = application_df['CLASSIFICATION'].value_counts()
classifications_to_replace = list(classification_counts[classification_counts < 1000].index)
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls, 'Other')

# %%
# Converting categorical data to numeric with pd.get_dummies
application_df = pd.get_dummies(application_df)

# %%
# Splitting data into features and target
X = application_df.drop(columns=['IS_SUCCESSFUL'])
y = application_df['IS_SUCCESSFUL']

# Splitting data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Creating a StandardScaler instance
scaler = StandardScaler()

# Fitting the StandardScaler
X_scaler = scaler.fit(X_train)

# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the filepath where you want to save the weights
checkpoint_path = "trained_charity_weights.{epoch:02d}.hdf5"

# Create a ModelCheckpoint callback
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,  # Save only the weights
    save_freq="epoch",  # Save weights every epoch
    period=5  # Save weights every five epochs
)

# Defining the model with more neurons and hidden layers, and different activation functions
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 200
hidden_nodes_layer2 = 100
hidden_nodes_layer3 = 50

nn = tf.keras.models.Sequential()

# First hidden layer with Leaky ReLU activation
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation=tf.keras.layers.LeakyReLU(alpha=0.01)))

# Second hidden layer with ELU activation
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='elu'))

# Third hidden layer with tanh activation
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='tanh'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 200)               7800
#
#  dense_1 (Dense)             (None, 100)               20100
#
#  dense_2 (Dense)             (None, 50)                5050
#
#  dense_3 (Dense)             (None, 1)                 51
#
# ...
# Total params: 33001 (128.91 KB)
# Trainable params: 33001 (128.91 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compiling the model with different learning rate and optimizer
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
nn.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
# Train the model
# Train the model with the added callback
# Training the model with increased epochs
fit_model = nn.fit(
    X_train_scaled,
    y_train,
    epochs=150,
    callbacks=[checkpoint_callback]  # Add the ModelCheckpoint callback
)
# Out:
# Epoch 1/150
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5844 - accuracy: 0.7129
# Epoch 2/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5634 - accuracy: 0.7297
# Epoch 3/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5591 - accuracy: 0.7309
# Epoch 4/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5568 - accuracy: 0.7306
# Epoch 5/150
# 799/804 [============================>.] - ETA: 0s - loss: 0.5554 - accuracy: 0.7310
# Epoch 5: saving model to trained_charity_weights.05.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5552 - accuracy: 0.7311
# Epoch 6/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5542 - accuracy: 0.7324
# Epoch 7/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5530 - accuracy: 0.7325
# Epoch 8/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5522 - accuracy: 0.7323
# Epoch 9/150
# ...

# %%
# Evaluating the model
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5566 - accuracy: 0.7263 - 671ms/epoch - 3ms/step
# Loss: 0.5566285252571106, Accuracy: 0.7262973785400391

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity_Optimization_3.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Download the file
files.download("AlphabetSoupCharity_Optimization_3.h5")
