# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
import shutil
from google.colab import files

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Dropping non-beneficial ID columns, 'EIN' and 'NAME', and additional irrelevant columns
application_df = application_df.drop(columns=['EIN', 'NAME', 'SPECIAL_CONSIDERATIONS'])

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE      17
# AFFILIATION            6
# CLASSIFICATION        71
# USE_CASE               5
# ORGANIZATION           4
# STATUS                 2
# INCOME_AMT             9
# ASK_AMT             8747
# IS_SUCCESSFUL          2
# dtype: int64

# %%
# Binning APPLICATION_TYPE with more bins for rare occurrences
application_counts = application_df['APPLICATION_TYPE'].value_counts()
application_types_to_replace = list(application_counts[application_counts < 1500].index)
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app, 'Other')

# Binning CLASSIFICATION with more bins for rare occurrences
classification_counts = application_df['CLASSIFICATION'].value_counts()
classifications_to_replace = list(classification_counts[classification_counts < 1000].index)
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls, 'Other')

# %%
# Converting categorical data to numeric with pd.get_dummies
application_df = pd.get_dummies(application_df)

# %%
# Splitting data into features and target
X = application_df.drop(columns=['IS_SUCCESSFUL'])
y = application_df['IS_SUCCESSFUL']

# Splitting data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Creating a StandardScaler instance
scaler = StandardScaler()

# Fitting the StandardScaler
X_scaler = scaler.fit(X_train)

# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the filepath where you want to save the weights
checkpoint_path = "trained_charity_weights.{epoch:02d}.hdf5"

# Create a ModelCheckpoint callback
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,  # Save only the weights
    save_freq="epoch",  # Save weights every epoch
    period=5  # Save weights every five epochs
)

# Defining the model with more neurons and hidden layers, and different activation functions
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 150
hidden_nodes_layer2 = 80
hidden_nodes_layer3 = 40

nn = tf.keras.models.Sequential()

# First hidden layer with Leaky ReLU activation
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation=tf.keras.layers.LeakyReLU(alpha=0.01)))

# Second hidden layer with ELU activation
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='elu'))

# Third hidden layer with ReLU activation
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 150)               5400
#
#  dense_1 (Dense)             (None, 80)                12080
#
#  dense_2 (Dense)             (None, 40)                3240
#
#  dense_3 (Dense)             (None, 1)                 41
#
# =================================================================
# Total params: 20761 (81.10 KB)
# Trainable params: 20761 (81.10 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compiling the model with different learning rate and optimizer
opt = tf.keras.optimizers.Adam(learning_rate=0.0005)
nn.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
# Train the model
# Train the model with the added callback
# Training the model with increased epochs
fit_model = nn.fit(
    X_train_scaled,
    y_train,
    epochs=200,
    callbacks=[checkpoint_callback]  # Add the ModelCheckpoint callback
)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5813 - accuracy: 0.7145
# Epoch 2/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5668 - accuracy: 0.7249
# Epoch 3/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5647 - accuracy: 0.7239
# Epoch 4/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5640 - accuracy: 0.7256
# Epoch 5/200
# 793/804 [============================>.] - ETA: 0s - loss: 0.5617 - accuracy: 0.7271
# Epoch 5: saving model to trained_charity_weights.05.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5621 - accuracy: 0.7267
# Epoch 6/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5614 - accuracy: 0.7271
# Epoch 7/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5607 - accuracy: 0.7270
# Epoch 8/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5601 - accuracy: 0.7280
# Epoch 9/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5598 - accuracy: 0.7274
# Epoch 10/200
# 787/804 [============================>.] - ETA: 0s - loss: 0.5587 - accuracy: 0.7281
# Epoch 10: saving model to trained_charity_weights.10.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5592 - accuracy: 0.7276
# Epoch 11/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5591 - accuracy: 0.7281
# Epoch 12/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5585 - accuracy: 0.7284
# Epoch 13/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5579 - accuracy: 0.7289
# Epoch 14/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5574 - accuracy: 0.7277
# Epoch 15/200
# 800/804 [============================>.] - ETA: 0s - loss: 0.5573 - accuracy: 0.7297
# Epoch 15: saving model to trained_charity_weights.15.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5574 - accuracy: 0.7296
# Epoch 16/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5577 - accuracy: 0.7285
# Epoch 17/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5568 - accuracy: 0.7298
# Epoch 18/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5567 - accuracy: 0.7301
# Epoch 19/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5563 - accuracy: 0.7294
# Epoch 20/200
# 794/804 [============================>.] - ETA: 0s - loss: 0.5566 - accuracy: 0.7297
# Epoch 20: saving model to trained_charity_weights.20.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5562 - accuracy: 0.7299
# Epoch 21/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5562 - accuracy: 0.7302
# Epoch 22/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5559 - accuracy: 0.7293
# Epoch 23/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5558 - accuracy: 0.7304
# Epoch 24/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5552 - accuracy: 0.7300
# Epoch 25/200
# 788/804 [============================>.] - ETA: 0s - loss: 0.5560 - accuracy: 0.7301
# Epoch 25: saving model to trained_charity_weights.25.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5557 - accuracy: 0.7304
# Epoch 26/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5550 - accuracy: 0.7302
# Epoch 27/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5547 - accuracy: 0.7313
# Epoch 28/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5547 - accuracy: 0.7305
# Epoch 29/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5543 - accuracy: 0.7312
# Epoch 30/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5548 - accuracy: 0.7309
# Epoch 30: saving model to trained_charity_weights.30.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5547 - accuracy: 0.7310
# Epoch 31/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5543 - accuracy: 0.7309
# Epoch 32/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5543 - accuracy: 0.7315
# Epoch 33/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5542 - accuracy: 0.7309
# Epoch 34/200
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5543 - accuracy: 0.7314
# Epoch 35/200
# 792/804 [============================>.] - ETA: 0s - loss: 0.5545 - accuracy: 0.7320
# Epoch 35: saving model to trained_charity_weights.35.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5539 - accuracy: 0.7325
# Epoch 36/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5536 - accuracy: 0.7314
# Epoch 37/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5536 - accuracy: 0.7317
# Epoch 38/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5536 - accuracy: 0.7311
# Epoch 39/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5533 - accuracy: 0.7313
# Epoch 40/200
# 792/804 [============================>.] - ETA: 0s - loss: 0.5532 - accuracy: 0.7315
# Epoch 40: saving model to trained_charity_weights.40.hdf5
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5532 - accuracy: 0.7317
# Epoch 41/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5532 - accuracy: 0.7313
# Epoch 42/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5531 - accuracy: 0.7322
# Epoch 43/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5528 - accuracy: 0.7321
# Epoch 44/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5524 - accuracy: 0.7327
# Epoch 45/200
# 790/804 [============================>.] - ETA: 0s - loss: 0.5534 - accuracy: 0.7312
# Epoch 45: saving model to trained_charity_weights.45.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5530 - accuracy: 0.7316
# Epoch 46/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5525 - accuracy: 0.7318
# Epoch 47/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5528 - accuracy: 0.7318
# Epoch 48/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5525 - accuracy: 0.7327
# Epoch 49/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5522 - accuracy: 0.7321
# Epoch 50/200
# 784/804 [============================>.] - ETA: 0s - loss: 0.5518 - accuracy: 0.7325
# Epoch 50: saving model to trained_charity_weights.50.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5517 - accuracy: 0.7324
# Epoch 51/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5521 - accuracy: 0.7325
# Epoch 52/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5523 - accuracy: 0.7320
# Epoch 53/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5521 - accuracy: 0.7326
# Epoch 54/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5514 - accuracy: 0.7326
# Epoch 55/200
# 799/804 [============================>.] - ETA: 0s - loss: 0.5517 - accuracy: 0.7319
# Epoch 55: saving model to trained_charity_weights.55.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5518 - accuracy: 0.7318
# Epoch 56/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5519 - accuracy: 0.7334
# Epoch 57/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5518 - accuracy: 0.7322
# Epoch 58/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5515 - accuracy: 0.7326
# Epoch 59/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5516 - accuracy: 0.7318
# Epoch 60/200
# 785/804 [============================>.] - ETA: 0s - loss: 0.5512 - accuracy: 0.7334
# Epoch 60: saving model to trained_charity_weights.60.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5515 - accuracy: 0.7326
# Epoch 61/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5513 - accuracy: 0.7321
# Epoch 62/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5514 - accuracy: 0.7329
# Epoch 63/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5513 - accuracy: 0.7328
# Epoch 64/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5510 - accuracy: 0.7325
# Epoch 65/200
# 796/804 [============================>.] - ETA: 0s - loss: 0.5510 - accuracy: 0.7325
# Epoch 65: saving model to trained_charity_weights.65.hdf5
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5508 - accuracy: 0.7325
# Epoch 66/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5510 - accuracy: 0.7323
# Epoch 67/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5512 - accuracy: 0.7329
# Epoch 68/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5509 - accuracy: 0.7331
# Epoch 69/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5509 - accuracy: 0.7326
# Epoch 70/200
# 799/804 [============================>.] - ETA: 0s - loss: 0.5515 - accuracy: 0.7316
# Epoch 70: saving model to trained_charity_weights.70.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5510 - accuracy: 0.7321
# Epoch 71/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5502 - accuracy: 0.7331
# Epoch 72/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5514 - accuracy: 0.7327
# Epoch 73/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7332
# Epoch 74/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5508 - accuracy: 0.7326
# Epoch 75/200
# 796/804 [============================>.] - ETA: 0s - loss: 0.5505 - accuracy: 0.7331
# Epoch 75: saving model to trained_charity_weights.75.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.7331
# Epoch 76/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.7333
# Epoch 77/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5503 - accuracy: 0.7333
# Epoch 78/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5503 - accuracy: 0.7337
# Epoch 79/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7325
# Epoch 80/200
# 792/804 [============================>.] - ETA: 0s - loss: 0.5495 - accuracy: 0.7339
# Epoch 80: saving model to trained_charity_weights.80.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5499 - accuracy: 0.7332
# Epoch 81/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.7327
# Epoch 82/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7331
# Epoch 83/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5499 - accuracy: 0.7339
# Epoch 84/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5498 - accuracy: 0.7332
# Epoch 85/200
# 792/804 [============================>.] - ETA: 0s - loss: 0.5496 - accuracy: 0.7335
# Epoch 85: saving model to trained_charity_weights.85.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5500 - accuracy: 0.7332
# Epoch 86/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5498 - accuracy: 0.7333
# Epoch 87/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5499 - accuracy: 0.7333
# Epoch 88/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5497 - accuracy: 0.7326
# Epoch 89/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5498 - accuracy: 0.7341
# Epoch 90/200
# 795/804 [============================>.] - ETA: 0s - loss: 0.5497 - accuracy: 0.7336
# Epoch 90: saving model to trained_charity_weights.90.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5495 - accuracy: 0.7334
# Epoch 91/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5495 - accuracy: 0.7333
# Epoch 92/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5494 - accuracy: 0.7338
# Epoch 93/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5494 - accuracy: 0.7337
# Epoch 94/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5497 - accuracy: 0.7330
# Epoch 95/200
# 800/804 [============================>.] - ETA: 0s - loss: 0.5493 - accuracy: 0.7335
# Epoch 95: saving model to trained_charity_weights.95.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5493 - accuracy: 0.7334
# Epoch 96/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5493 - accuracy: 0.7332
# Epoch 97/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5494 - accuracy: 0.7338
# Epoch 98/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5491 - accuracy: 0.7339
# Epoch 99/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5493 - accuracy: 0.7341
# Epoch 100/200
# 789/804 [============================>.] - ETA: 0s - loss: 0.5495 - accuracy: 0.7334
# Epoch 100: saving model to trained_charity_weights.100.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5495 - accuracy: 0.7334
# Epoch 101/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5492 - accuracy: 0.7332
# Epoch 102/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5487 - accuracy: 0.7333
# Epoch 103/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5494 - accuracy: 0.7331
# Epoch 104/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5490 - accuracy: 0.7336
# Epoch 105/200
# 788/804 [============================>.] - ETA: 0s - loss: 0.5486 - accuracy: 0.7336
# Epoch 105: saving model to trained_charity_weights.105.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5489 - accuracy: 0.7332
# Epoch 106/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5491 - accuracy: 0.7333
# Epoch 107/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5485 - accuracy: 0.7334
# Epoch 108/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5489 - accuracy: 0.7336
# Epoch 109/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5488 - accuracy: 0.7338
# Epoch 110/200
# 794/804 [============================>.] - ETA: 0s - loss: 0.5480 - accuracy: 0.7340
# Epoch 110: saving model to trained_charity_weights.110.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5488 - accuracy: 0.7333
# Epoch 111/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5489 - accuracy: 0.7332
# Epoch 112/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5484 - accuracy: 0.7335
# Epoch 113/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5486 - accuracy: 0.7339
# Epoch 114/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5483 - accuracy: 0.7338
# Epoch 115/200
# 800/804 [============================>.] - ETA: 0s - loss: 0.5484 - accuracy: 0.7341
# Epoch 115: saving model to trained_charity_weights.115.hdf5
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5485 - accuracy: 0.7340
# Epoch 116/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5485 - accuracy: 0.7340
# Epoch 117/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5486 - accuracy: 0.7339
# Epoch 118/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5493 - accuracy: 0.7336
# Epoch 119/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5482 - accuracy: 0.7333
# Epoch 120/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5486 - accuracy: 0.7338
# Epoch 120: saving model to trained_charity_weights.120.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5486 - accuracy: 0.7337
# Epoch 121/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5483 - accuracy: 0.7340
# Epoch 122/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5482 - accuracy: 0.7343
# Epoch 123/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5483 - accuracy: 0.7332
# Epoch 124/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5484 - accuracy: 0.7339
# Epoch 125/200
# 786/804 [============================>.] - ETA: 0s - loss: 0.5487 - accuracy: 0.7329
# Epoch 125: saving model to trained_charity_weights.125.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5485 - accuracy: 0.7332
# Epoch 126/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5485 - accuracy: 0.7339
# Epoch 127/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5483 - accuracy: 0.7340
# Epoch 128/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7343
# Epoch 129/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5487 - accuracy: 0.7337
# Epoch 130/200
# 793/804 [============================>.] - ETA: 0s - loss: 0.5479 - accuracy: 0.7345
# Epoch 130: saving model to trained_charity_weights.130.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5480 - accuracy: 0.7344
# Epoch 131/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5480 - accuracy: 0.7340
# Epoch 132/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5480 - accuracy: 0.7339
# Epoch 133/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5480 - accuracy: 0.7340
# Epoch 134/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5479 - accuracy: 0.7334
# Epoch 135/200
# 789/804 [============================>.] - ETA: 0s - loss: 0.5479 - accuracy: 0.7338
# Epoch 135: saving model to trained_charity_weights.135.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5481 - accuracy: 0.7339
# Epoch 136/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5484 - accuracy: 0.7337
# Epoch 137/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5480 - accuracy: 0.7342
# Epoch 138/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5479 - accuracy: 0.7339
# Epoch 139/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5475 - accuracy: 0.7340
# Epoch 140/200
# 781/804 [============================>.] - ETA: 0s - loss: 0.5480 - accuracy: 0.7341
# Epoch 140: saving model to trained_charity_weights.140.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5477 - accuracy: 0.7339
# Epoch 141/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5480 - accuracy: 0.7343
# Epoch 142/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5477 - accuracy: 0.7343
# Epoch 143/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5473 - accuracy: 0.7342
# Epoch 144/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7343
# Epoch 145/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5482 - accuracy: 0.7343
# Epoch 145: saving model to trained_charity_weights.145.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5482 - accuracy: 0.7343
# Epoch 146/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5476 - accuracy: 0.7345
# Epoch 147/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5475 - accuracy: 0.7336
# Epoch 148/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7342
# Epoch 149/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5487 - accuracy: 0.7343
# Epoch 150/200
# 801/804 [============================>.] - ETA: 0s - loss: 0.5476 - accuracy: 0.7339
# Epoch 150: saving model to trained_charity_weights.150.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5475 - accuracy: 0.7339
# Epoch 151/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5476 - accuracy: 0.7338
# Epoch 152/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5472 - accuracy: 0.7347
# Epoch 153/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5477 - accuracy: 0.7337
# Epoch 154/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5476 - accuracy: 0.7344
# Epoch 155/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5475 - accuracy: 0.7342
# Epoch 155: saving model to trained_charity_weights.155.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5475 - accuracy: 0.7342
# Epoch 156/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5475 - accuracy: 0.7343
# Epoch 157/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5479 - accuracy: 0.7343
# Epoch 158/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5475 - accuracy: 0.7340
# Epoch 159/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5473 - accuracy: 0.7346
# Epoch 160/200
# 800/804 [============================>.] - ETA: 0s - loss: 0.5475 - accuracy: 0.7338
# Epoch 160: saving model to trained_charity_weights.160.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5472 - accuracy: 0.7340
# Epoch 161/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5476 - accuracy: 0.7343
# Epoch 162/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5474 - accuracy: 0.7340
# Epoch 163/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5487 - accuracy: 0.7338
# Epoch 164/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5471 - accuracy: 0.7347
# Epoch 165/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5468 - accuracy: 0.7343
# Epoch 165: saving model to trained_charity_weights.165.hdf5
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5469 - accuracy: 0.7343
# Epoch 166/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5473 - accuracy: 0.7344
# Epoch 167/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5471 - accuracy: 0.7344
# Epoch 168/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5471 - accuracy: 0.7348
# Epoch 169/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5475 - accuracy: 0.7345
# Epoch 170/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5468 - accuracy: 0.7347
# Epoch 170: saving model to trained_charity_weights.170.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5471 - accuracy: 0.7344
# Epoch 171/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5470 - accuracy: 0.7341
# Epoch 172/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5475 - accuracy: 0.7344
# Epoch 173/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5470 - accuracy: 0.7338
# Epoch 174/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5471 - accuracy: 0.7349
# Epoch 175/200
# 790/804 [============================>.] - ETA: 0s - loss: 0.5476 - accuracy: 0.7345
# Epoch 175: saving model to trained_charity_weights.175.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5479 - accuracy: 0.7341
# Epoch 176/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7342
# Epoch 177/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5474 - accuracy: 0.7340
# Epoch 178/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5468 - accuracy: 0.7348
# Epoch 179/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5470 - accuracy: 0.7345
# Epoch 180/200
# 788/804 [============================>.] - ETA: 0s - loss: 0.5477 - accuracy: 0.7344
# Epoch 180: saving model to trained_charity_weights.180.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5470 - accuracy: 0.7345
# Epoch 181/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5470 - accuracy: 0.7337
# Epoch 182/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5469 - accuracy: 0.7344
# Epoch 183/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5468 - accuracy: 0.7348
# Epoch 184/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5470 - accuracy: 0.7341
# Epoch 185/200
# 798/804 [============================>.] - ETA: 0s - loss: 0.5467 - accuracy: 0.7344
# Epoch 185: saving model to trained_charity_weights.185.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5467 - accuracy: 0.7346
# Epoch 186/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5470 - accuracy: 0.7343
# Epoch 187/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5471 - accuracy: 0.7344
# Epoch 188/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5469 - accuracy: 0.7346
# Epoch 189/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5469 - accuracy: 0.7344
# Epoch 190/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5469 - accuracy: 0.7343
# Epoch 190: saving model to trained_charity_weights.190.hdf5
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5468 - accuracy: 0.7343
# Epoch 191/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5487 - accuracy: 0.7345
# Epoch 192/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5486 - accuracy: 0.7342
# Epoch 193/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5465 - accuracy: 0.7347
# Epoch 194/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5467 - accuracy: 0.7342
# Epoch 195/200
# 789/804 [============================>.] - ETA: 0s - loss: 0.5461 - accuracy: 0.7353
# Epoch 195: saving model to trained_charity_weights.195.hdf5
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5466 - accuracy: 0.7348
# Epoch 196/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5467 - accuracy: 0.7346
# Epoch 197/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5469 - accuracy: 0.7346
# Epoch 198/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5469 - accuracy: 0.7341
# Epoch 199/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5468 - accuracy: 0.7346
# Epoch 200/200
# 789/804 [============================>.] - ETA: 0s - loss: 0.5466 - accuracy: 0.7342
# Epoch 200: saving model to trained_charity_weights.200.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5469 - accuracy: 0.7339

# %%
# Evaluating the model
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5770 - accuracy: 0.7200 - 1s/epoch - 4ms/step
# Loss: 0.5770368576049805, Accuracy: 0.7200000286102295

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity_Optimization_2.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Download the file
files.download("AlphabetSoupCharity_Optimization_2.h5")
